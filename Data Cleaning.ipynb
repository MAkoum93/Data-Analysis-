# %%
# Assignment 1

###  Mohamed Akoum 
###  ID : 26567762
# Comp 333 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# adding a new feature to the data set tip_rate
df = pd.read_csv('Desktop/tips.csv')
df.assign(tip_rate = lambda x: 0.18 - 0.01*df['size'])
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size  tip_rate
# 0             1       16.99  1.01  Female     No   Sun  Dinner     2      0.16
# 1             2       10.34  1.66    Male     No   Sun  Dinner     3      0.15
# 2             3       21.01  3.50    Male     No   Sun  Dinner     3      0.15
# 3             4       23.68  3.31    Male     No   Sun  Dinner     2      0.16
# 4             5       24.59  3.61  Female     No   Sun  Dinner     4      0.14
# ..          ...         ...   ...     ...    ...   ...     ...   ...       ...
# 239         240       29.03  5.92    Male     No   Sat  Dinner     3      0.15
# 240         241       27.18  2.00  Female    Yes   Sat  Dinner     2      0.16
# 241         242       22.67  2.00    Male    Yes   Sat  Dinner     2      0.16
# 242         243       17.82  1.75    Male     No   Sat  Dinner     2      0.16
# 243         244       18.78  3.00  Female     No  Thur  Dinner     2      0.16
#
# [244 rows x 9 columns]

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0  total_bill         tip   sex smoker  day    time  \
# count   244.000000  244.000000  244.000000   244    244  244     244
# unique         NaN         NaN         NaN     2      2    4       2
# top            NaN         NaN         NaN  Male     No  Sat  Dinner
# freq           NaN         NaN         NaN   157    151   87     176
# mean    122.500000   19.785943    2.998279   NaN    NaN  NaN     NaN
# std      70.580923    8.902412    1.383638   NaN    NaN  NaN     NaN
# min       1.000000    3.070000    1.000000   NaN    NaN  NaN     NaN
# 25%      61.750000   13.347500    2.000000   NaN    NaN  NaN     NaN
# 50%     122.500000   17.795000    2.900000   NaN    NaN  NaN     NaN
# 75%     183.250000   24.127500    3.562500   NaN    NaN  NaN     NaN
# max     244.000000   50.810000   10.000000   NaN    NaN  NaN     NaN
#
#               size
# count   244.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean      2.569672
# ...

# %%
# dataset: total_bill is an INTERVAL DATA TYPE
# dataset: tip is a RATIO DATA TYPE
# dataset: sex is a NOMINAL DATA TYPE
# dataset: smoker is a NOMINAL DATA TYPE
# dataset: day is a NOMINAL DATA TYPE since the year data type is not present if it were then day will be an ordinal data type
# dataset: time in this case is an ORDINAL DATA TYPE 
# dataset: size is an INTERVAL DATA TYPE
# dataset: tip_rate is a RATIO DATA TYPE

# %%
# The distribution of values is skewed right and unimodal

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Desktop/tips.csv')

data = df['tip']

plt.hist(data, bins = np.arange(0.51, 11.5, 1))

plt.show()

# %%
# peaks occur at the whole-dollar and half-dollar amounts

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
data = df['tip']

plt.hist(data, bins=np.arange(0.5, 10.5, 0.1))

plt.show()

# %%
# there are more points far away from the line in the lower right than in the upper left, indicating that more customers are very cheap than very generous.

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv('Desktop/tips.csv')



sns.regplot(x='total_bill',y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Smoking parties have a lot more variability in the tips that they give. Males tend to pay the (few) higher bills, and the female non-smokers tend to be very consistent tippers 
sns.lmplot(x="total_bill", y="tip", col="sex", row="smoker",ci=False,data=df, height=5.5, aspect =1);
